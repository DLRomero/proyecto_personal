# %%
# -----------------------------------------------------------------------
import os 

# Regex
# -----------------------------------------------------------------------
import re

# Tratamiento de datos
# -----------------------------------------------------------------------
import numpy as np
import pandas as pd

# Gráficos
# ------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
#plt.rcParams["figure.figsize"] = (10,8) 


#  Gestión de warnings
# ------------------------------------------------------------------------------
import warnings
warnings.filterwarnings('ignore')

#  Visual jupyter
# ------------------------------------------------------------------------------
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
sprint= pd.read_csv('./Data/sprint_resume.csv',index_col=0)
sprint.head()
# Out:
#    resultid  raceid  driverid  constructorid  number_x  grid position  \
# 0        61    1077       830              9         1     1        1
# 1        62    1077       844              6        16     2        2
# 2        63    1077       815              9        11     7        3
# 3        64    1077       832              6        55    10        4
# 4        65    1077       846              1         4     3        5
#
#   positiontext  positionorder  points  laps sprint_time milliseconds  \
# 0            1              1       8    21   30:39.567      1839567
# 1            2              2       7    21      +2.975      1842542
# 2            3              3       6    21      +4.721      1844288
# 3            4              4       5    21     +17.578      1857145
# 4            5              5       4    21     +24.561      1864128
#
#   fastestlap fastestlaptime  statusid code      driver_name constructor  \
# 0         14       1:19.154         1  VER   Max Verstappen    Red Bull
# 1         11       1:19.044         1  LEC  Charles Leclerc     Ferrari
# 2         14       1:19.012         1  PER     Sergio Pérez    Red Bull
# 3         14       1:19.251         1  SAI     Carlos Sainz     Ferrari
# 4          9       1:20.030         1  NOR     Lando Norris     McLaren
#
#    round  circuitid                    circuit        date  \
# 0      4         21  Emilia Romagna Grand Prix  2022-04-24
# 1      4         21  Emilia Romagna Grand Prix  2022-04-24
# 2      4         21  Emilia Romagna Grand Prix  2022-04-24
# 3      4         21  Emilia Romagna Grand Prix  2022-04-24
# 4      4         21  Emilia Romagna Grand Prix  2022-04-24
#
#                                                  url    fp1_date  fp1_time  \
# 0  http://en.wikipedia.org/wiki/2022_Emilia_Romag...  2022-04-22  11:30:00
# 1  http://en.wikipedia.org/wiki/2022_Emilia_Romag...  2022-04-22  11:30:00
# 2  http://en.wikipedia.org/wiki/2022_Emilia_Romag...  2022-04-22  11:30:00
# 3  http://en.wikipedia.org/wiki/2022_Emilia_Romag...  2022-04-22  11:30:00
# 4  http://en.wikipedia.org/wiki/2022_Emilia_Romag...  2022-04-22  11:30:00
#
#      fp2_date  fp2_time fp3_date fp3_time  quali_date quali_time sprint_date  \
# 0  2022-04-23  10:30:00       \N       \N  2022-04-22   15:00:00  2022-04-23
# 1  2022-04-23  10:30:00       \N       \N  2022-04-22   15:00:00  2022-04-23
# 2  2022-04-23  10:30:00       \N       \N  2022-04-22   15:00:00  2022-04-23
# 3  2022-04-23  10:30:00       \N       \N  2022-04-22   15:00:00  2022-04-23
# 4  2022-04-23  10:30:00       \N       \N  2022-04-22   15:00:00  2022-04-23
#
#   sprint_time.1
# 0      14:30:00
# 1      14:30:00
# 2      14:30:00
# 3      14:30:00
# 4      14:30:00

# %%
qualys= pd.read_csv('./Data/qualys_resume.csv',index_col=0)
qualys.head()
# Out:
#    qualifyid  raceid  driverid  constructorid  position        q1        q2  \
# 0       9176    1074       844              6         1  1:31.471  1:30.932
# 1       9177    1074       830              9         2  1:31.785  1:30.757
# 2       9178    1074       832              6         3  1:31.567  1:30.787
# 3       9179    1074       815              9         4  1:32.311  1:31.008
# 4       9180    1074         1            131         5  1:32.285  1:31.048
#
#          q3 code      driver_name constructor  year  round  circuitid  \
# 0  1:30.558  LEC  Charles Leclerc     Ferrari  2022      1          3
# 1  1:30.681  VER   Max Verstappen    Red Bull  2022      1          3
# 2  1:30.687  SAI     Carlos Sainz     Ferrari  2022      1          3
# 3  1:30.921  PER     Sergio Pérez    Red Bull  2022      1          3
# 4  1:31.238  HAM   Lewis Hamilton    Mercedes  2022      1          3
#
#               circuit        date      time  \
# 0  Bahrain Grand Prix  2022-03-20  15:00:00
# 1  Bahrain Grand Prix  2022-03-20  15:00:00
# 2  Bahrain Grand Prix  2022-03-20  15:00:00
# 3  Bahrain Grand Prix  2022-03-20  15:00:00
# 4  Bahrain Grand Prix  2022-03-20  15:00:00
#
#                                                  url    fp1_date  fp1_time  \
# 0  http://en.wikipedia.org/wiki/2022_Bahrain_Gran...  2022-03-18  12:00:00
# 1  http://en.wikipedia.org/wiki/2022_Bahrain_Gran...  2022-03-18  12:00:00
# 2  http://en.wikipedia.org/wiki/2022_Bahrain_Gran...  2022-03-18  12:00:00
# 3  http://en.wikipedia.org/wiki/2022_Bahrain_Gran...  2022-03-18  12:00:00
# 4  http://en.wikipedia.org/wiki/2022_Bahrain_Gran...  2022-03-18  12:00:00
#
#      fp2_date  fp2_time    fp3_date  fp3_time  quali_date quali_time  \
# 0  2022-03-18  15:00:00  2022-03-19  12:00:00  2022-03-19   15:00:00
# 1  2022-03-18  15:00:00  2022-03-19  12:00:00  2022-03-19   15:00:00
# 2  2022-03-18  15:00:00  2022-03-19  12:00:00  2022-03-19   15:00:00
# 3  2022-03-18  15:00:00  2022-03-19  12:00:00  2022-03-19   15:00:00
# 4  2022-03-18  15:00:00  2022-03-19  12:00:00  2022-03-19   15:00:00
#
#   sprint_date sprint_time
# 0          \N          \N
# 1          \N          \N
# 2          \N          \N
# 3          \N          \N
# 4          \N          \N

# %%
results= pd.read_csv('./Data/results_resume.csv',index_col=0)
results.head()
# Out:
#    resultid  raceid  driverid  constructorid  grid position positiontext  \
# 0     25406    1074       844              6     1        1            1
# 1     25407    1074       832              6     3        2            2
# 2     25408    1074         1            131     5        3            3
# 3     25409    1074       847            131     9        4            4
# 4     25410    1074       825            210     7        5            5
#
#    positionorder  points  laps         time milliseconds fastestlap  rank  \
# 0              1    26.0    57  1:37:33.584      5853584         51     1
# 1              2    18.0    57       +5.598      5859182         52     3
# 2              3    15.0    57       +9.675      5863259         53     5
# 3              4    12.0    57      +11.211      5864795         56     6
# 4              5    10.0    57      +14.754      5868338         53     8
#
#   fastestlaptime fastestlapspeed  statusid code      driver_name  \
# 0       1:34.570         206.018         1  LEC  Charles Leclerc
# 1       1:35.740         203.501         1  SAI     Carlos Sainz
# 2       1:36.228         202.469         1  HAM   Lewis Hamilton
# 3       1:36.302         202.313         1  RUS   George Russell
# 4       1:36.623         201.641         1  MAG  Kevin Magnussen
#
#     constructor  year  round  circuitid             circuit        date  \
# 0       Ferrari  2022      1          3  Bahrain Grand Prix  2022-03-20
# 1       Ferrari  2022      1          3  Bahrain Grand Prix  2022-03-20
# 2      Mercedes  2022      1          3  Bahrain Grand Prix  2022-03-20
# 3      Mercedes  2022      1          3  Bahrain Grand Prix  2022-03-20
# 4  Haas F1 Team  2022      1          3  Bahrain Grand Prix  2022-03-20
#
#                                                  url    fp1_date  fp1_time  \
# 0  http://en.wikipedia.org/wiki/2022_Bahrain_Gran...  2022-03-18  12:00:00
# 1  http://en.wikipedia.org/wiki/2022_Bahrain_Gran...  2022-03-18  12:00:00
# 2  http://en.wikipedia.org/wiki/2022_Bahrain_Gran...  2022-03-18  12:00:00
# 3  http://en.wikipedia.org/wiki/2022_Bahrain_Gran...  2022-03-18  12:00:00
# 4  http://en.wikipedia.org/wiki/2022_Bahrain_Gran...  2022-03-18  12:00:00
#
#      fp2_date  fp2_time    fp3_date  fp3_time  quali_date quali_time  \
# 0  2022-03-18  15:00:00  2022-03-19  12:00:00  2022-03-19   15:00:00
# 1  2022-03-18  15:00:00  2022-03-19  12:00:00  2022-03-19   15:00:00
# 2  2022-03-18  15:00:00  2022-03-19  12:00:00  2022-03-19   15:00:00
# 3  2022-03-18  15:00:00  2022-03-19  12:00:00  2022-03-19   15:00:00
# 4  2022-03-18  15:00:00  2022-03-19  12:00:00  2022-03-19   15:00:00
#
#   sprint_date sprint_time  overtakes
# 0          \N          \N          0
# 1          \N          \N          1
# 2          \N          \N          2
# 3          \N          \N          5
# 4          \N          \N          2

# %%
results['circuit'].value_counts()
# Out:
# Bahrain Grand Prix           20
# Saudi Arabian Grand Prix     20
# United States Grand Prix     20
# Japanese Grand Prix          20
# Singapore Grand Prix         20
# Italian Grand Prix           20
# Dutch Grand Prix             20
# Belgian Grand Prix           20
# Hungarian Grand Prix         20
# French Grand Prix            20
# Austrian Grand Prix          20
# British Grand Prix           20
# Canadian Grand Prix          20
# Azerbaijan Grand Prix        20
# Monaco Grand Prix            20
# Spanish Grand Prix           20
# Miami Grand Prix             20
# Emilia Romagna Grand Prix    20
# Australian Grand Prix        20
# Mexico City Grand Prix       20
# Name: circuit, dtype: int64
